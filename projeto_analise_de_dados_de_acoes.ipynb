# %% [markdown]
# ## Projeto - Análise de dados de ações

# %% [markdown]
# ### Leitura de dados com yfinance

# %% [markdown]
# https://pypi.org/project/yfinance/

# %%
import yfinance as yf

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
petr = yf.Ticker("PETR4.SA")

# %%
petr.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   1.366446   1.366446   1.366446   1.366446
# 2000-01-04 00:00:00-02:00   1.290855   1.290855   1.290855   1.290855
# 2000-01-05 00:00:00-02:00   1.277830   1.277830   1.277830   1.277830
# 2000-01-06 00:00:00-02:00   1.273411   1.273411   1.273411   1.273411
# 2000-01-07 00:00:00-02:00   1.279226   1.279226   1.279226   1.279226
# ...                              ...        ...        ...        ...
# 2024-09-20 00:00:00-03:00  36.270000  36.400002  36.070000  36.259998
# 2024-09-23 00:00:00-03:00  36.389999  36.959999  36.220001  36.630001
# 2024-09-24 00:00:00-03:00  37.230000  37.310001  36.720001  36.779999
# 2024-09-25 00:00:00-03:00  37.099998  37.430000  36.959999  37.049999
# 2024-09-26 00:00:00-03:00  36.919998  36.919998  35.970001  36.310001
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-02:00  35389440000        0.0           0.0
# 2000-01-04 00:00:00-02:00  28861440000        0.0           0.0
# 2000-01-05 00:00:00-02:00  43033600000        0.0           0.0
# 2000-01-06 00:00:00-02:00  34055680000        0.0           0.0
# 2000-01-07 00:00:00-02:00  20912640000        0.0           0.0
# ...                                ...        ...           ...
# 2024-09-20 00:00:00-03:00     48336200        0.0           0.0
# 2024-09-23 00:00:00-03:00     28218500        0.0           0.0
# 2024-09-24 00:00:00-03:00     35104100        0.0           0.0
# 2024-09-25 00:00:00-03:00     38655300        0.0           0.0
# 2024-09-26 00:00:00-03:00     41520600        0.0           0.0
#
# [6214 rows x 7 columns]

# %%
petr.history(period="max")["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petr.info
# Out:
# {'address1': 'Avenida Henrique Valadares, 28',
#  'address2': '19th floor',
#  'city': 'Rio De Janeiro',
#  'state': 'RJ',
#  'zip': '20241-030',
#  'country': 'Brazil',
#  'website': 'https://petrobras.com.br',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Petróleo Brasileiro S.A. - Petrobras explores, produces, and sells oil and gas in Brazil and internationally. The company operates through three segments: Exploration and Production; Refining, Transportation and Marketing; and Gas and Power. The Exploration and Production segment explores, develops, and produces crude oil, natural gas liquids, and natural gas primarily for supplies to the domestic refineries. The Refining, Transportation and Marketing segment engages in the refining, logistics, transport, acquisition, and exports of crude oil; and production of fertilizers, as well as holding interests in petrochemical companies. The Gas and Power segment is involved in the logistic and trading of natural gas and electricity; transportation and trading of LNG; generation of electricity through thermoelectric power plants; renewable energy businesses; low carbon services; and natural gas processing business, as well as production of biodiesel and its co-products. The company also engages in prospecting, drilling, refining, processing, trading, and transporting crude oil from producing onshore and offshore oil fields, and shale or other rocks, as well as oil products, natural gas, and other liquid hydrocarbons. In addition, it engages in research, development, production, transport, distribution, and trading of energy. Petróleo Brasileiro S.A. - Petrobras was incorporated in 1953 and is headquartered in Rio de Janeiro, Brazil.',
#  'fullTimeEmployees': 46730,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Ms. Magda Maria de Regina Chambriard',
#    'title': 'CEO & Non-Independent Director',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Clarice  Coppetti',
#    'age': 59,
#    'title': 'Interim President, Chief Corporate Affairs Officer & Member of Executive Board',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Fernando Sabbi Melgarejo',
#    'title': 'Chief Financial & Investor Relations Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mario Vinicius Claussen Spinelli',
#    'age': 52,
#    'title': 'Chief Governance & Compliance Officer and Member of Executive Board',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Claudio Romeo Schlosser',
#    'age': 59,
#    'title': 'Chief Logistics, Commercialization & Markets Officer and Member of Executive Board',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. William Franca da Silva',
#    'age': 63,
#    'title': 'Chief Industrial Processes & Products Officer and Member of Executive Board',
#    'yearBorn': 1960,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mauricio Tiomno Tolmasquim',
#    'age': 65,
#    'title': 'Chief Energy Transition & Sustainability Officer and Member of Executive Board',
#    'yearBorn': 1958,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Renata  Baruzzi',
#    'title': 'Chief Engineering, Technology, & Innovation Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hélio Siqueira Júnior',
#    'title': 'Acting General Counsel',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bruno  Motta',
#    'title': 'Executive Manager of Communication & Brands',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 5,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 10,
#  'overallRisk': 3,
#  'governanceEpochDate': 1726617600,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 37.05,
#  'open': 36.92,
#  'dayLow': 35.97,
#  'dayHigh': 36.92,
#  'regularMarketPreviousClose': 37.05,
#  'regularMarketOpen': 36.92,
#  'regularMarketDayLow': 35.97,
#  'regularMarketDayHigh': 36.92,
#  'dividendRate': 5.02,
#  'dividendYield': 0.1356,
#  'exDividendDate': 1724284800,
#  'payoutRatio': 1.0286,
#  'fiveYearAvgDividendYield': 18.46,
#  'beta': 0.992,
#  'trailingPE': 5.372781,
#  'forwardPE': 4.277974,
#  'volume': 41527200,
#  'regularMarketVolume': 41527200,
#  'averageVolume': 32947581,
#  'averageVolume10days': 31704220,
#  'averageDailyVolume10Day': 31704220,
#  'bid': 36.31,
#  'ask': 36.32,
#  'marketCap': 493508886528,
#  'fiftyTwoWeekLow': 32.29,
#  'fiftyTwoWeekHigh': 42.94,
#  'priceToSalesTrailing12Months': 0.988867,
#  'fiftyDayAverage': 37.54,
#  'twoHundredDayAverage': 38.4391,
#  'trailingAnnualDividendRate': 5.32,
#  'trailingAnnualDividendYield': 0.14358975,
#  'currency': 'BRL',
#  'enterpriseValue': 743884521472,
#  'profitMargins': 0.15782,
#  'floatShares': 7950930353,
#  'sharesOutstanding': 5446499840,
#  'heldPercentInsiders': 0.16073,
#  'heldPercentInstitutions': 0.35959,
#  'impliedSharesOutstanding': 13587800064,
#  'bookValue': 28.977,
#  'priceToBook': 1.253408,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1719705600,
#  'netIncomeToCommon': 78762999808,
#  'trailingEps': 6.76,
#  'forwardEps': 8.49,
#  'pegRatio': -0.68,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1209340800,
#  'enterpriseToRevenue': 1.491,
#  'enterpriseToEbitda': 3.301,
#  '52WeekChange': 0.07547164,
#  'SandP52WeekChange': 0.33085096,
#  'lastDividendValue': 1.0532,
#  'lastDividendDate': 1724284800,
#  'exchange': 'SAO',
#  'quoteType': 'EQUITY',
#  'symbol': 'PETR4.SA',
#  'underlyingSymbol': 'PETR4.SA',
#  'shortName': 'PETROBRAS   PN      N2',
#  'longName': 'Petróleo Brasileiro S.A. - Petrobras',
#  'firstTradeDateEpochUtc': 946900800,
#  'timeZoneFullName': 'America/Sao_Paulo',
#  'timeZoneShortName': 'BRT',
#  'uuid': 'f698f172-aeef-3c5e-887d-d45f94bdd057',
#  'messageBoardId': 'finmb_409268',
#  'gmtOffSetMilliseconds': -10800000,
#  'currentPrice': 36.32,
#  'targetHighPrice': 49.0,
#  'targetLowPrice': 33.0,
#  'targetMeanPrice': 43.39,
#  'targetMedianPrice': 44.5,
#  'recommendationMean': 2.2,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 10,
#  'totalCash': 67676999680,
#  'totalCashPerShare': 5.251,
#  'ebitda': 225348993024,
#  'totalDebt': 331472994304,
#  'quickRatio': 0.605,
#  'currentRatio': 0.895,
#  'totalRevenue': 499064995840,
#  'debtToEquity': 88.148,
#  'revenuePerShare': 38.524,
#  'returnOnAssets': 0.1122,
#  'returnOnEquity': 0.21172,
#  'freeCashflow': 108373377024,
#  'operatingCashflow': 207837003776,
#  'revenueGrowth': 0.074,
#  'grossMargins': 0.52235,
#  'ebitdaMargins': 0.45154,
#  'operatingMargins': 0.30754998,
#  'financialCurrency': 'BRL',
#  'trailingPegRatio': 2.4555}

# %%
petr.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2005-04-01 00:00:00-03:00   0.079975           0.0
# 2005-07-01 00:00:00-03:00   0.250663           0.0
# 2005-09-01 00:00:00-03:00   0.000000           4.0
# 2006-01-02 00:00:00-02:00   0.259000           0.0
# 2006-04-04 00:00:00-03:00   0.185750           0.0
# 2006-11-01 00:00:00-03:00   0.500750           0.0
# 2007-01-02 00:00:00-02:00   0.225000           0.0
# 2007-04-03 00:00:00-03:00   0.175000           0.0
# 2007-08-20 00:00:00-03:00   0.251700           0.0
# 2007-10-08 00:00:00-03:00   0.256500           0.0
# 2008-01-14 00:00:00-02:00   0.155300           0.0
# 2008-04-07 00:00:00-03:00   0.102600           0.0
# 2008-04-28 00:00:00-03:00   0.000000           2.0
# 2008-12-29 00:00:00-02:00   0.042600           0.0
# 2009-04-09 00:00:00-03:00   0.351600           0.0
# 2009-07-06 00:00:00-03:00   0.300000           0.0
# 2009-10-01 00:00:00-03:00   0.200000           0.0
# 2009-12-21 00:00:00-02:00   0.200000           0.0
# 2010-04-23 00:00:00-03:00   0.133200           0.0
# 2010-05-24 00:00:00-03:00   0.170000           0.0
# 2010-08-02 00:00:00-03:00   0.170000           0.0
# 2010-11-03 00:00:00-02:00   0.140000           0.0
# 2010-12-22 00:00:00-02:00   0.200000           0.0
# 2011-03-22 00:00:00-03:00   0.173420           0.0
# 2011-04-29 00:00:00-03:00   0.126500           0.0
# 2011-05-12 00:00:00-03:00   0.213600           0.0
# 2011-08-03 00:00:00-03:00   0.207300           0.0
# 2011-11-14 00:00:00-02:00   0.200000           0.0
# 2012-01-03 00:00:00-02:00   0.177300           0.0
# 2012-03-20 00:00:00-03:00   0.124400           0.0
# 2012-05-14 00:00:00-03:00   0.200000           0.0
# 2013-04-30 00:00:00-03:00   0.380000           0.0
# 2014-04-03 00:00:00-03:00   0.967200           0.0
# 2018-05-22 00:00:00-03:00   0.050000           0.0
# 2018-08-14 00:00:00-03:00   0.050000           0.0
# 2018-11-22 00:00:00-02:00   0.100000           0.0
# 2018-12-26 00:00:00-02:00   0.716563           0.0
# 2019-04-26 00:00:00-03:00   0.019494           0.0
# 2019-05-22 00:00:00-03:00   0.100000           0.0
# 2019-08-13 00:00:00-03:00   0.200000           0.0
# 2019-11-12 00:00:00-03:00   0.200925           0.0
# 2019-12-27 00:00:00-03:00   0.421942           0.0
# 2020-07-23 00:00:00-03:00   0.000461           0.0
# 2021-04-15 00:00:00-03:00   0.792834           0.0
# 2021-08-17 00:00:00-03:00   1.609911           0.0
# 2021-12-02 00:00:00-03:00   3.250487           0.0
# 2022-04-14 00:00:00-03:00   2.970249           0.0
# 2022-05-24 00:00:00-03:00   3.715490           0.0
# 2022-08-12 00:00:00-03:00   6.667932           0.0
# 2022-11-22 00:00:00-03:00   1.748708           0.0
# 2023-04-28 00:00:00-03:00   2.930163           0.0
# 2023-06-13 00:00:00-03:00   1.893576           0.0
# 2023-08-22 00:00:00-03:00   1.149304           0.0
# 2023-11-22 00:00:00-03:00   1.371248           0.0
# 2024-04-26 00:00:00-03:00   1.150024           0.0
# 2024-05-03 00:00:00-03:00   1.776022           0.0
# 2024-06-12 00:00:00-03:00   1.043242           0.0
# 2024-08-22 00:00:00-03:00   1.053200           0.0

# %% [markdown]
# ```
# petr.financials
# petr.quarterly_financials
#
# # show major holders
# petr.major_holders
#
# # show institutional holders
# petr.institutional_holders
#
# # show balance sheet
# petr.balance_sheet
# petr.quarterly_balance_sheet
#
# # show cashflow
# petr.cashflow
# petr.quarterly_cashflow
#
# # show earnings
# petr.earnings
# petr.quarterly_earnings
# ```

# %%
tickers = yf.Tickers('PETR4.SA ABEV3.SA AMER3.SA')

# %%
tickers.tickers
# Out:
# {'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'AMER3.SA': yfinance.Ticker object <AMER3.SA>}

# %%
tickers.tickers["PETR4.SA"].balance_sheet
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                              104359669.0
# Preferred Shares Number                                     NaN
# Ordinary Shares Number                            12940137261.0
# Share Issued                                      13044496930.0
# Net Debt                                          16074000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  15546000000.0
# Other Short Term Investments                       2819000000.0
# Cash And Cash Equivalents                         12727000000.0
# Cash Equivalents                                  12624000000.0
# Cash Financial                                      103000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                                 295669.0
# Preferred Shares Number                                     NaN
# Ordinary Shares Number                            13044201261.0
# Share Issued                                      13044496930.0
# Net Debt                                          21958000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  10769000000.0
# Other Short Term Investments                       2773000000.0
# Cash And Cash Equivalents                          7996000000.0
# Cash Equivalents                                   7780000000.0
# Cash Financial                                      216000000.0
#
#                                                      2021-12-31  \
# Treasury Shares Number                                 295669.0
# Preferred Shares Number                            5601969879.0
# Ordinary Shares Number                            13044201261.0
# Share Issued                                      13044496930.0
# Net Debt                                          25233000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  11117000000.0
# Other Short Term Investments                        650000000.0
# Cash And Cash Equivalents                         10467000000.0
# Cash Equivalents                                  10168000000.0
# Cash Financial                                      299000000.0
#
#                                                      2020-12-31 2019-12-31
# Treasury Shares Number                                 295669.0        NaN
# Preferred Shares Number                                     NaN        NaN
# Ordinary Shares Number                            13044201261.0        NaN
# Share Issued                                      13044496930.0        NaN
# Net Debt                                          42177000000.0        NaN
# ...                                                         ...        ...
# Cash Cash Equivalents And Short Term Investments  12370000000.0        NaN
# Other Short Term Investments                        659000000.0        NaN
# Cash And Cash Equivalents                         11711000000.0        NaN
# Cash Equivalents                                  11159000000.0        NaN
# Cash Financial                                      552000000.0        NaN
#
# [86 rows x 5 columns]

# %% [markdown]
# ## Ibovespa
# https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm

# %%
df_ibov = pd.read_csv("ibovdia_09-08-22.csv")
df_ibov
# Out:
#    Código          Ação        Tipo  Qtde. Teórica Part. (%)
# 0   RRRP3  3R PETROLEUM  ON      NM    200.372.163     0,341
# 1   ALPA4    ALPARGATAS  PN      N1    201.257.220     0,193
# 2   ABEV3     AMBEV S/A          ON  4.380.195.841     3,214
# 3   AMER3    AMERICANAS  ON      NM    596.875.824     0,421
# 4   ASAI3         ASSAI  ON      NM    794.531.367     0,682
# ..    ...           ...         ...            ...       ...
# 85  VALE3          VALE  ON      NM  3.768.748.489    12,817
# 86  VIIA3           VIA  ON      NM  1.596.295.753     0,231
# 87  VBBR3         VIBRA  ON      NM  1.131.883.365     1,016
# 88  WEGE3           WEG  ON      NM  1.484.859.030     2,189
# 89  YDUQ3    YDUQS PART  ON      NM    300.833.122     0,231
#
# [90 rows x 5 columns]

# %%
df_ibov["Part. (%)"] = df_ibov["Part. (%)"].apply(lambda x: float(x.replace(",", ".")))

# %% [markdown]
# #### 1. Vamos analisar o histórico das 10 ações com maior participacão na bolsa. Encontre estes ativos no DataFrame `df_ibov` e carregue-os em um objeto Tickers do módulo do Yahoo.

# %%
acoes = df_ibov.sort_values("Part. (%)").tail(10)["Código"].values

# %% [markdown]
# ```
# # Criamos uma lista com as palavras "how", "are" e "you"
# my_list = ["how", "are", "you"]
#
# # Usamos o método join para unir os itens da lista em uma única string,colocando um espaço (" ") entre cada palavra
# resultado = " ".join(my_list)  # O resultado será: "how are you"
# ```

# %%
" ".join(acoes)
# Out:
# 'RENT3 ELET3 BBAS3 ABEV3 B3SA3 BBDC4 PETR3 ITUB4 PETR4 VALE3'

# %%
tickers = yf.Tickers(" ".join([i + '.SA' for i in acoes]))
tickers.tickers
# Out:
# {'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'VALE3.SA': yfinance.Ticker object <VALE3.SA>}

# %% [markdown]
# #### 2. Crie um dicionário que conterá como chaves os tickers de cada ativo (PETR4.SA, por exemplo) e como valores um DataFrame contendo os dados históricos de cada

# %%
tickers.tickers
# Out:
# {'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'VALE3.SA': yfinance.Ticker object <VALE3.SA>}

# %%
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando: {}".format(ticker))
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")
# Out:
# Baixando: RENT3.SA
# Baixando: ELET3.SA
# Baixando: BBAS3.SA
# Baixando: ABEV3.SA
# Baixando: B3SA3.SA
# Baixando: BBDC4.SA
# Baixando: PETR3.SA
# Baixando: ITUB4.SA
# Baixando: PETR4.SA
# Baixando: VALE3.SA

# %%
dict_data["ITUB4.SA"]
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-12-21 00:00:00-02:00   1.570666   1.667193   1.570481   1.651582
# 2000-12-22 00:00:00-02:00   1.634956   1.634956   1.570297   1.579996
# 2000-12-25 00:00:00-02:00   1.579996   1.579996   1.579996   1.579996
# 2000-12-26 00:00:00-02:00   1.571312   1.581380   1.556440   1.579533
# 2000-12-27 00:00:00-02:00   1.607245   1.633109   1.579534   1.633109
# ...                              ...        ...        ...        ...
# 2024-09-20 00:00:00-03:00  36.320000  36.480000  35.910000  35.930000
# 2024-09-23 00:00:00-03:00  35.740002  35.980000  35.570000  35.720001
# 2024-09-24 00:00:00-03:00  36.049999  36.330002  35.520000  35.709999
# 2024-09-25 00:00:00-03:00  35.779999  36.169998  35.779999  36.160000
# 2024-09-26 00:00:00-03:00  36.500000  36.750000  36.340000  36.720001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2000-12-21 00:00:00-02:00     74224    0.00000           0.0
# 2000-12-22 00:00:00-02:00     23312    0.00000           0.0
# 2000-12-25 00:00:00-02:00         0    0.00000           0.0
# 2000-12-26 00:00:00-02:00      7851    0.00000           0.0
# 2000-12-27 00:00:00-02:00     26996    0.00000           0.0
# ...                             ...        ...           ...
# 2024-09-20 00:00:00-03:00  30654600    0.27298           0.0
# 2024-09-23 00:00:00-03:00  15333800    0.00000           0.0
# 2024-09-24 00:00:00-03:00  24014400    0.00000           0.0
# 2024-09-25 00:00:00-03:00  21696900    0.00000           0.0
# 2024-09-26 00:00:00-03:00  18105000    0.00000           0.0
#
# [5961 rows x 7 columns]

# %% [markdown]
# #### 3. Combine todos os dados em um único DataFrame, utilizando o preço de fechamento de cada ativo.

# %%
df_data = pd.DataFrame()

for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how="outer")

# %%
df_data
# Out:
#                             RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN   8.896824   0.494708        NaN
# 2000-01-04 00:00:00-02:00        NaN   8.466698   0.471178        NaN
# 2000-01-05 00:00:00-02:00        NaN   8.806274   0.476005   0.296132
# 2000-01-06 00:00:00-02:00        NaN   8.602528   0.482642   0.281121
# 2000-01-07 00:00:00-02:00        NaN   8.738356   0.471782   0.281121
# ...                              ...        ...        ...        ...
# 2024-09-20 00:00:00-03:00  42.589790  39.930000  27.500000  12.760000
# 2024-09-23 00:00:00-03:00  42.302555  39.549999  27.400000  12.750000
# 2024-09-24 00:00:00-03:00  42.669029  39.650002  27.379999  12.760000
# 2024-09-25 00:00:00-03:00  41.480476  39.160000  27.299999  12.680000
# 2024-09-26 00:00:00-03:00  41.950001  39.630001  27.610001  12.820000
#
#                             B3SA3.SA  BBDC4.SA   PETR3.SA   ITUB4.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN       NaN   1.332575        NaN
# 2000-01-04 00:00:00-02:00        NaN       NaN   1.257787        NaN
# 2000-01-05 00:00:00-02:00        NaN       NaN   1.274784        NaN
# 2000-01-06 00:00:00-02:00        NaN       NaN   1.264586        NaN
# 2000-01-07 00:00:00-02:00        NaN       NaN   1.274784        NaN
# ...                              ...       ...        ...        ...
# 2024-09-20 00:00:00-03:00  11.501363     14.75  39.700001  35.930000
# 2024-09-23 00:00:00-03:00  11.104764     14.37  40.200001  35.720001
# 2024-09-24 00:00:00-03:00  11.154339     14.35  40.500000  35.709999
# 2024-09-25 00:00:00-03:00  10.790000     14.44  40.529999  36.160000
# 2024-09-26 00:00:00-03:00  10.820000     14.77  39.750000  36.720001
#
#                             PETR4.SA   VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00   1.366446   1.475653
# 2000-01-04 00:00:00-02:00   1.290855   1.440519
# 2000-01-05 00:00:00-02:00   1.277831   1.440519
# 2000-01-06 00:00:00-02:00   1.273411   1.440519
# 2000-01-07 00:00:00-02:00   1.279226   1.493221
# ...                              ...        ...
# 2024-09-20 00:00:00-03:00  36.259998  57.349998
# 2024-09-23 00:00:00-03:00  36.630001  57.529999
# 2024-09-24 00:00:00-03:00  36.779999  60.340000
# 2024-09-25 00:00:00-03:00  37.049999  60.610001
# 2024-09-26 00:00:00-03:00  36.320000  64.000000
#
# [6214 rows x 10 columns]

# %% [markdown]
# #### 4. Qual a primeira data na qual todos os ativos estudados já estavam na bolsa?

# %%
df_data.dropna().index[0]
# Out:
# Timestamp('2008-01-02 00:00:00-0200', tz='America/Sao_Paulo')

# %% [markdown]
# #### 5. Crie um DataFrame adicional para representar a variação percentual diária de cada ativo

# %%
df_ret = df_data / df_data.shift(1) - 1
df_ret
# Out:
#                            RENT3.SA  ELET3.SA  BBAS3.SA  ABEV3.SA  B3SA3.SA  \
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00       NaN -0.048346 -0.047562       NaN       NaN
# 2000-01-05 00:00:00-02:00       NaN  0.040107  0.010244       NaN       NaN
# 2000-01-06 00:00:00-02:00       NaN -0.023137  0.013942 -0.050691       NaN
# 2000-01-07 00:00:00-02:00       NaN  0.015789 -0.022500  0.000000       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-20 00:00:00-03:00 -0.029564 -0.030825 -0.014690 -0.014672 -0.033333
# 2024-09-23 00:00:00-03:00 -0.006744 -0.009517 -0.003636 -0.000784 -0.034483
# 2024-09-24 00:00:00-03:00  0.008663  0.002529 -0.000730  0.000784  0.004464
# 2024-09-25 00:00:00-03:00 -0.027855 -0.012358 -0.002922 -0.006270 -0.032663
# 2024-09-26 00:00:00-03:00  0.011319  0.012002  0.011355  0.011041  0.002780
#
#                            BBDC4.SA  PETR3.SA  ITUB4.SA  PETR4.SA  VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00       NaN -0.056122       NaN -0.055319 -0.023809
# 2000-01-05 00:00:00-02:00       NaN  0.013513       NaN -0.010090  0.000000
# 2000-01-06 00:00:00-02:00       NaN -0.008000       NaN -0.003459  0.000000
# 2000-01-07 00:00:00-02:00       NaN  0.008065       NaN  0.004566  0.036585
# ...                             ...       ...       ...       ...       ...
# 2024-09-20 00:00:00-03:00 -0.018629  0.000000 -0.010929 -0.000276 -0.015113
# 2024-09-23 00:00:00-03:00 -0.025763  0.012594 -0.005845  0.010204  0.003139
# 2024-09-24 00:00:00-03:00 -0.001392  0.007463 -0.000280  0.004095  0.048844
# 2024-09-25 00:00:00-03:00  0.006272  0.000741  0.012602  0.007341  0.004475
# 2024-09-26 00:00:00-03:00  0.022853 -0.019245  0.015487 -0.019703  0.055931
#
# [6214 rows x 10 columns]

# %% [markdown]
# #### 6. Quais foram as datas na qual cada ativo apresentou sua pior oscilação? Apresente também a variação percentual.

# %%
df_ret.idxmin()
# Out:
# RENT3.SA   2020-03-16 00:00:00-03:00
# ELET3.SA   2010-02-01 00:00:00-02:00
# BBAS3.SA   2016-03-15 00:00:00-03:00
# ABEV3.SA   2005-04-04 00:00:00-03:00
# B3SA3.SA   2011-05-09 00:00:00-03:00
# BBDC4.SA   2009-05-29 00:00:00-03:00
# PETR3.SA   2020-03-09 00:00:00-03:00
# ITUB4.SA   2021-10-04 00:00:00-03:00
# PETR4.SA   2020-03-09 00:00:00-03:00
# VALE3.SA   2019-01-28 00:00:00-02:00
# dtype: datetime64[ns, America/Sao_Paulo]

# %%
df_ret.min()
# Out:
# RENT3.SA   -0.234222
# ELET3.SA   -0.220074
# BBAS3.SA   -0.211712
# ABEV3.SA   -0.224263
# B3SA3.SA   -0.661335
# BBDC4.SA   -0.432507
# PETR3.SA   -0.296758
# ITUB4.SA   -0.179643
# PETR4.SA   -0.296978
# VALE3.SA   -0.245592
# dtype: float64

# %% [markdown]
# #### 7. Analisando esta série temporal, você conseguira estimar se existe uma maior probabilidade dos ativos performarem bem logo após um dia de queda?

# %%
df_ret
# Out:
#                            RENT3.SA  ELET3.SA  BBAS3.SA  ABEV3.SA  B3SA3.SA  \
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00       NaN -0.048346 -0.047562       NaN       NaN
# 2000-01-05 00:00:00-02:00       NaN  0.040107  0.010244       NaN       NaN
# 2000-01-06 00:00:00-02:00       NaN -0.023137  0.013942 -0.050691       NaN
# 2000-01-07 00:00:00-02:00       NaN  0.015789 -0.022500  0.000000       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-20 00:00:00-03:00 -0.029564 -0.030825 -0.014690 -0.014672 -0.033333
# 2024-09-23 00:00:00-03:00 -0.006744 -0.009517 -0.003636 -0.000784 -0.034483
# 2024-09-24 00:00:00-03:00  0.008663  0.002529 -0.000730  0.000784  0.004464
# 2024-09-25 00:00:00-03:00 -0.027855 -0.012358 -0.002922 -0.006270 -0.032663
# 2024-09-26 00:00:00-03:00  0.011319  0.012002  0.011355  0.011041  0.002780
#
#                            BBDC4.SA  PETR3.SA  ITUB4.SA  PETR4.SA  VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00       NaN -0.056122       NaN -0.055319 -0.023809
# 2000-01-05 00:00:00-02:00       NaN  0.013513       NaN -0.010090  0.000000
# 2000-01-06 00:00:00-02:00       NaN -0.008000       NaN -0.003459  0.000000
# 2000-01-07 00:00:00-02:00       NaN  0.008065       NaN  0.004566  0.036585
# ...                             ...       ...       ...       ...       ...
# 2024-09-20 00:00:00-03:00 -0.018629  0.000000 -0.010929 -0.000276 -0.015113
# 2024-09-23 00:00:00-03:00 -0.025763  0.012594 -0.005845  0.010204  0.003139
# 2024-09-24 00:00:00-03:00 -0.001392  0.007463 -0.000280  0.004095  0.048844
# 2024-09-25 00:00:00-03:00  0.006272  0.000741  0.012602  0.007341  0.004475
# 2024-09-26 00:00:00-03:00  0.022853 -0.019245  0.015487 -0.019703  0.055931
#
# [6214 rows x 10 columns]

# %%
df_ret[df_ret.shift(1) < 0].mean()
# Out:
# RENT3.SA    0.001154
# ELET3.SA   -0.000013
# BBAS3.SA    0.000505
# ABEV3.SA    0.001090
# B3SA3.SA    0.001198
# BBDC4.SA    0.000669
# PETR3.SA    0.000464
# ITUB4.SA    0.000434
# PETR4.SA    0.000608
# VALE3.SA    0.000367
# dtype: float64

# %%
df_ret[df_ret.shift(1) < 0].std()
# Out:
# RENT3.SA    0.027257
# ELET3.SA    0.030667
# BBAS3.SA    0.027735
# ABEV3.SA    0.018295
# B3SA3.SA    0.028384
# BBDC4.SA    0.024195
# PETR3.SA    0.028903
# ITUB4.SA    0.022769
# PETR4.SA    0.028371
# VALE3.SA    0.025349
# dtype: float64

# %%
df_study = df_ret[df_ret.shift(1) < 0]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))

print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# RENT3 - 0.11539503574420817
# ELET3 - -0.001345628488990508
# BBAS3 - 0.0505447707713139
# ABEV3 - 0.10898499643696327
# B3SA3 - 0.11978259674695592
# BBDC4 - 0.06693857538379888
# PETR3 - 0.04638526563784111
# ITUB4 - 0.0433963833961524
# PETR4 - 0.060832893666161
# VALE3 - 0.03671180952400559
# Desvio padrão dos retornos
# RENT3 - 2.725736692018044
# ELET3 - 3.066715945529932
# BBAS3 - 2.773471290955021
# ABEV3 - 1.829539563704943
# B3SA3 - 2.838421349868558
# BBDC4 - 2.4194841336224147
# PETR3 - 2.890252279801089
# ITUB4 - 2.276857778020644
# PETR4 - 2.837107401619284
# VALE3 - 2.5349141349918214

# %% [markdown]
# #### 8. Seguindo a lógica da questão anterior, avalie como em média se comportam as ações no pregão seguinte a quedas maiores que 1%. De posse destes dados, você acredita que seria uma boa estratégia de investimento comprar ações que cairam no dia anterior?

# %%
df_study = df_ret[df_ret.shift(1) < -0.05]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))

print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# RENT3 - 0.3083927665007252
# ELET3 - 0.1308589291730855
# BBAS3 - 0.5126804663854926
# ABEV3 - 1.1917981965676039
# B3SA3 - 0.055504443294989554
# BBDC4 - 1.237718522809117
# PETR3 - 0.1465926653221596
# ITUB4 - 0.46672288178530397
# PETR4 - 0.10531193776235355
# VALE3 - 0.19817122895862968
# Desvio padrão dos retornos
# RENT3 - 6.306531046052584
# ELET3 - 4.930424748515449
# BBAS3 - 4.555236423980018
# ABEV3 - 4.278140705705711
# B3SA3 - 6.193583314734917
# BBDC4 - 6.08245550992536
# PETR3 - 5.4015497811463575
# ITUB4 - 4.885573448824227
# PETR4 - 5.853506028242109
# VALE3 - 4.873618373347611

# %% [markdown]
# ### DESAFIOS

# %% [markdown]
# #### 9. De tempos em tempos, empresas podem distribuir lucro aos acionistas na forma de dividendos. Podemos obter o histórico de pagamentos de dividendos usando a yfinance. Um indicador muito utilizado no mercado é o Dividend Yield (DY), que é calculado somando-se o total pago de dividendos no ano e dividindo pela cotação da ação. Calcule o DY anual de cada ativo.

# %%
df_data
# Out:
#                             RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN   8.896824   0.494708        NaN
# 2000-01-04 00:00:00-02:00        NaN   8.466698   0.471178        NaN
# 2000-01-05 00:00:00-02:00        NaN   8.806274   0.476005   0.296132
# 2000-01-06 00:00:00-02:00        NaN   8.602528   0.482642   0.281121
# 2000-01-07 00:00:00-02:00        NaN   8.738356   0.471782   0.281121
# ...                              ...        ...        ...        ...
# 2024-09-20 00:00:00-03:00  42.589790  39.930000  27.500000  12.760000
# 2024-09-23 00:00:00-03:00  42.302555  39.549999  27.400000  12.750000
# 2024-09-24 00:00:00-03:00  42.669029  39.650002  27.379999  12.760000
# 2024-09-25 00:00:00-03:00  41.480476  39.160000  27.299999  12.680000
# 2024-09-26 00:00:00-03:00  41.950001  39.630001  27.610001  12.820000
#
#                             B3SA3.SA  BBDC4.SA   PETR3.SA   ITUB4.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN       NaN   1.332575        NaN
# 2000-01-04 00:00:00-02:00        NaN       NaN   1.257787        NaN
# 2000-01-05 00:00:00-02:00        NaN       NaN   1.274784        NaN
# 2000-01-06 00:00:00-02:00        NaN       NaN   1.264586        NaN
# 2000-01-07 00:00:00-02:00        NaN       NaN   1.274784        NaN
# ...                              ...       ...        ...        ...
# 2024-09-20 00:00:00-03:00  11.501363     14.75  39.700001  35.930000
# 2024-09-23 00:00:00-03:00  11.104764     14.37  40.200001  35.720001
# 2024-09-24 00:00:00-03:00  11.154339     14.35  40.500000  35.709999
# 2024-09-25 00:00:00-03:00  10.790000     14.44  40.529999  36.160000
# 2024-09-26 00:00:00-03:00  10.820000     14.77  39.750000  36.720001
#
#                             PETR4.SA   VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00   1.366446   1.475653
# 2000-01-04 00:00:00-02:00   1.290855   1.440519
# 2000-01-05 00:00:00-02:00   1.277831   1.440519
# 2000-01-06 00:00:00-02:00   1.273411   1.440519
# 2000-01-07 00:00:00-02:00   1.279226   1.493221
# ...                              ...        ...
# 2024-09-20 00:00:00-03:00  36.259998  57.349998
# 2024-09-23 00:00:00-03:00  36.630001  57.529999
# 2024-09-24 00:00:00-03:00  36.779999  60.340000
# 2024-09-25 00:00:00-03:00  37.049999  60.610001
# 2024-09-26 00:00:00-03:00  36.320000  64.000000
#
# [6214 rows x 10 columns]

# %%
tickers.tickers['RENT3.SA'].dividends
# Out:
# Date
# 2007-12-20 00:00:00-02:00    0.010572
# 2008-03-28 00:00:00-03:00    0.010502
# 2008-04-09 00:00:00-03:00    0.035020
# 2008-04-11 00:00:00-03:00    0.035325
# 2008-07-03 00:00:00-03:00    0.010301
#                                ...
# 2023-09-28 00:00:00-03:00    0.405298
# 2023-12-27 00:00:00-03:00    0.382055
# 2024-04-02 00:00:00-03:00    0.382740
# 2024-06-27 00:00:00-03:00    0.397984
# 2024-09-26 00:00:00-03:00    0.399526
# Name: Dividends, Length: 80, dtype: float64

# %%
df_dividends = pd.DataFrame()

for ticker in tickers.tickers.keys():
    df_dividends_aux = tickers.tickers[ticker].dividends.to_frame().rename(columns={"Dividends": ticker})
    df_dividends = df_dividends.join(df_dividends_aux, how='outer')

# %%
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando: {}".format(ticker))
    # Baixa o histórico completo
    historico = tickers.tickers[ticker].history(period="max")
    # Remove o horário de cada data no índice
    historico.index = historico.index.date
    dict_data[ticker] = historico
# Out:
# Baixando: RENT3.SA
# Baixando: ELET3.SA
# Baixando: BBAS3.SA
# Baixando: ABEV3.SA
# Baixando: B3SA3.SA
# Baixando: BBDC4.SA
# Baixando: PETR3.SA
# Baixando: ITUB4.SA
# Baixando: PETR4.SA
# Baixando: VALE3.SA

# %%
df_dividends
# Out:
#                            RENT3.SA  ELET3.SA  BBAS3.SA  ABEV3.SA  B3SA3.SA  \
# Date
# 2005-04-01 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2005-07-01 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2006-01-02 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2006-04-04 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2006-11-01 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-03 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2024-09-12 00:00:00-03:00       NaN       NaN  0.186602       NaN       NaN
# 2024-09-20 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2024-09-25 00:00:00-03:00       NaN       NaN       NaN       NaN  0.095661
# 2024-09-26 00:00:00-03:00  0.399526       NaN       NaN       NaN       NaN
#
#                            BBDC4.SA  PETR3.SA  ITUB4.SA  PETR4.SA  VALE3.SA
# Date
# 2005-04-01 00:00:00-03:00       NaN       NaN       NaN  0.079975       NaN
# 2005-07-01 00:00:00-03:00       NaN       NaN       NaN  0.250663       NaN
# 2006-01-02 00:00:00-02:00       NaN       NaN       NaN  0.259000       NaN
# 2006-04-04 00:00:00-03:00       NaN       NaN       NaN  0.185750       NaN
# 2006-11-01 00:00:00-03:00       NaN       NaN       NaN  0.500750       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-03 00:00:00-03:00  0.018975       NaN       NaN       NaN       NaN
# 2024-09-12 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2024-09-20 00:00:00-03:00       NaN       NaN   0.27298       NaN       NaN
# 2024-09-25 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
# 2024-09-26 00:00:00-03:00       NaN       NaN       NaN       NaN       NaN
#
# [757 rows x 10 columns]

# %%
df_dividends['year'] = df_dividends.index.year
df_data["year"] = df_data.index.year

# %%
df_dividends_year = df_dividends.groupby("year").sum()
df_last_price = df_data.dropna().groupby("year").last()

# %%
df_yield = df_dividends_year/df_last_price  * 100
df_yield.dropna(inplace=True)

# %%
df_yield
# Out:
#       RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA   BBDC4.SA  \
# year
# 2008  7.509218   3.490004   0.000000   5.221684  0.701050   3.269233
# 2009  1.082783   8.737860   8.016792   1.944358  1.341918   1.641822
# 2010  0.775018  30.191270  14.295460   2.233234  2.023959   2.086589
# 2011  1.747392   8.308641  18.360421   3.204798  8.704881   6.244373
# 2012  1.442728  33.260282  13.891859   4.417766  4.781037   4.725784
# 2013  5.256054  30.583097  19.269819   2.268820  7.488301   5.025627
# 2014  1.612294   8.496656  12.917344   5.370366  5.953773   5.062270
# 2015  3.131698   0.000000  23.416863  11.866056  9.939319  11.092334
# 2016  2.957428   0.000000   5.204489   5.047477  4.008118   6.685853
# 2017  1.249922   0.000000   4.611273   3.192201  2.556464   5.173879
# 2018  1.002921   0.000000   4.849634   4.356308  3.268395   4.035483
# 2019  0.910276   2.643392   9.753592   3.119150  2.287975   9.571183
# 2020  0.546290   4.947970   5.047658   3.056964  3.083249   3.143910
# 2021  0.900167   7.446857   9.668890   4.887014  9.147729   6.230784
# 2022  2.598377   1.868406  10.319642   5.524417  3.818341   3.310359
# 2023  2.425567   0.526328   5.693026   5.318281  3.462060   9.164470
# 2024  2.813468   1.018930   5.531181   0.000000  3.711830   3.830941
#
#        PETR3.SA  ITUB4.SA   PETR4.SA   VALE3.SA
# year
# 2008   0.533361  0.000000   5.039374   4.863916
# 2009   8.476020  0.000000  10.624259   4.673347
# 2010   8.686779  1.365392  10.726264   3.960477
# 2011  12.469184  6.484134  14.850270  13.455757
# 2012   7.916508  3.752700   8.699762  10.752114
# 2013   2.573008  5.058579   7.390620   5.379801
# 2014  16.575720  4.413754  30.042047  15.774299
# 2015   0.000000  8.462570   0.000000  12.989799
# 2016   0.000000  6.632983   0.000000   1.117157
# 2017   0.000000  4.772699   0.000000   5.438347
# 2018   2.893177  5.960098  12.068838   6.128678
# 2019   4.503597  6.013693   9.025123   4.103885
# 2020   2.368107  2.954008   0.004702   4.086806
# 2021  42.802730  5.005570  46.681016  23.710900
# 2022  85.208985  4.526324  90.604603   9.823713
# 2023  21.248697  3.925741  22.387424   6.328898
# 2024  12.635190  5.582121  13.828436   7.550541

# %% [markdown]
# #### 10. Avalie o desempenho de uma estratégia de investimento que monta uma carteira de ações ano a ano com as 3 maiores pagadoras de dividendo do ano anterior. Compare o desempenho dela com o desempenho de uma carteira global.

# %%
df_ret_year = df_last_price / df_last_price.shift(1) - 1

# %%
((df_ret_year / 10).sum(axis=1) + 1).cumprod().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df_yield.iloc[0, :].nlargest(3).index
# Out:
# Index(['RENT3.SA', 'ABEV3.SA', 'PETR4.SA'], dtype='object')

# %%
df_yield
# Out:
#       RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA   BBDC4.SA  \
# year
# 2008  7.509218   3.490004   0.000000   5.221684  0.701050   3.269233
# 2009  1.082783   8.737860   8.016792   1.944358  1.341918   1.641822
# 2010  0.775018  30.191270  14.295460   2.233234  2.023959   2.086589
# 2011  1.747392   8.308641  18.360421   3.204798  8.704881   6.244373
# 2012  1.442728  33.260282  13.891859   4.417766  4.781037   4.725784
# 2013  5.256054  30.583097  19.269819   2.268820  7.488301   5.025627
# 2014  1.612294   8.496656  12.917344   5.370366  5.953773   5.062270
# 2015  3.131698   0.000000  23.416863  11.866056  9.939319  11.092334
# 2016  2.957428   0.000000   5.204489   5.047477  4.008118   6.685853
# 2017  1.249922   0.000000   4.611273   3.192201  2.556464   5.173879
# 2018  1.002921   0.000000   4.849634   4.356308  3.268395   4.035483
# 2019  0.910276   2.643392   9.753592   3.119150  2.287975   9.571183
# 2020  0.546290   4.947970   5.047658   3.056964  3.083249   3.143910
# 2021  0.900167   7.446857   9.668890   4.887014  9.147729   6.230784
# 2022  2.598377   1.868406  10.319642   5.524417  3.818341   3.310359
# 2023  2.425567   0.526328   5.693026   5.318281  3.462060   9.164470
# 2024  2.813468   1.018930   5.531181   0.000000  3.711830   3.830941
#
#        PETR3.SA  ITUB4.SA   PETR4.SA   VALE3.SA
# year
# 2008   0.533361  0.000000   5.039374   4.863916
# 2009   8.476020  0.000000  10.624259   4.673347
# 2010   8.686779  1.365392  10.726264   3.960477
# 2011  12.469184  6.484134  14.850270  13.455757
# 2012   7.916508  3.752700   8.699762  10.752114
# 2013   2.573008  5.058579   7.390620   5.379801
# 2014  16.575720  4.413754  30.042047  15.774299
# 2015   0.000000  8.462570   0.000000  12.989799
# 2016   0.000000  6.632983   0.000000   1.117157
# 2017   0.000000  4.772699   0.000000   5.438347
# 2018   2.893177  5.960098  12.068838   6.128678
# 2019   4.503597  6.013693   9.025123   4.103885
# 2020   2.368107  2.954008   0.004702   4.086806
# 2021  42.802730  5.005570  46.681016  23.710900
# 2022  85.208985  4.526324  90.604603   9.823713
# 2023  21.248697  3.925741  22.387424   6.328898
# 2024  12.635190  5.582121  13.828436   7.550541

# %%
strategy_return = []

for i in range(len(df_yield) - 1):
    stocks = df_yield.iloc[i, :].nlargest(3).index
    strategy_return += [(df_ret_year[stocks].iloc[i + 1] / 3).sum() + 1]

# %%
df_global = df_ret_year / 10

fig, ax = plt.subplots()
pd.DataFrame(strategy_return, index=df_global.index[1:]).cumprod().plot(color="red", ax=ax)
(df_global.sum(axis=1) + 1).cumprod().plot(color="blue", ax=ax)
# Out:
# <Axes: xlabel='year'>
